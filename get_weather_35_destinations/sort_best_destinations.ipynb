# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('weather_to_sort.csv')

# %%
df.drop(labels='Unnamed: 0', axis=1, inplace=True)

# %%
cols = df.columns.tolist()

# %%
cols = ['cityname',
 'coordinates',
 'temperature_j1',
 'precipitation_j1',
 'weathercode_j1',
 'temperature_j2',
 'precipitation_j2',
 'weathercode_j2',
 'temperature_j3',
 'precipitation_j3',
 'weathercode_j3',
 'temperature_j4',
 'precipitation_j4',
 'weathercode_j4',
 'temperature_j5',
 'precipitation_j5',
 'weathercode_j5',
 'temperature_j6',
 'precipitation_j6',
 'weathercode_j6',
 'temperature_j7',
 'precipitation_j7',
 'weathercode_j7',
 ]

# %%
df = df[cols]

# %%
df.shape
# Out:
# (35, 23)

# %%
df.head(5)
# Out:
#             cityname                           coordinates  temperature_j1  \
# 0  Mont+Saint+Michel  ('48.6359541', '-1.511459954959514')            14.8
# 1            St+Malo           ('48.649518', '-2.0260409')            14.9
# 2             Bayeux          ('49.2764624', '-0.7024738')            14.6
# 3           Le+Havre           ('49.4938975', '0.1079732')            12.6
# 4              Rouen           ('49.4404591', '1.0939658')            12.2
#
#    precipitation_j1  weathercode_j1  temperature_j2  precipitation_j2  \
# 0               0.0               3            15.5               0.0
# 1               0.0               3            15.6               0.0
# 2               0.0               3            16.0               0.0
# 3               0.0               3            15.1               0.0
# 4               1.1              61            15.4               0.0
#
#    weathercode_j2  temperature_j3  precipitation_j3  weathercode_j3  \
# ...

# %%
df['mean_temp'] = df.iloc[:,2::3].mean(axis=1)
df['sum_precipitation'] = df.iloc[:,3::3].sum(axis=1)
df['top_weather_code'] = df.iloc[:, 4::3].max(axis=1)

# %%
df.head()
# Out:
#             cityname                           coordinates  temperature_j1  \
# 0  Mont+Saint+Michel  ('48.6359541', '-1.511459954959514')            14.8
# 1            St+Malo           ('48.649518', '-2.0260409')            14.9
# 2             Bayeux          ('49.2764624', '-0.7024738')            14.6
# 3           Le+Havre           ('49.4938975', '0.1079732')            12.6
# 4              Rouen           ('49.4404591', '1.0939658')            12.2
#
#    precipitation_j1  weathercode_j1  temperature_j2  precipitation_j2  \
# 0               0.0               3            15.5               0.0
# 1               0.0               3            15.6               0.0
# 2               0.0               3            16.0               0.0
# 3               0.0               3            15.1               0.0
# 4               1.1              61            15.4               0.0
#
#    weathercode_j2  temperature_j3  precipitation_j3  weathercode_j3  \
# ...

# %%
df.columns
# Out:
# Index(['cityname', 'coordinates', 'temperature_j1', 'precipitation_j1',
#        'weathercode_j1', 'temperature_j2', 'precipitation_j2',
#        'weathercode_j2', 'temperature_j3', 'precipitation_j3',
#        'weathercode_j3', 'temperature_j4', 'precipitation_j4',
#        'weathercode_j4', 'temperature_j5', 'precipitation_j5',
#        'weathercode_j5', 'temperature_j6', 'precipitation_j6',
#        'weathercode_j6', 'temperature_j7', 'precipitation_j7',
#        'weathercode_j7', 'mean_temp', 'sum_precipitation', 'top_weather_code'],
#       dtype='object')

# %%
df_sorted = df.sort_values(['mean_temp','sum_precipitation','top_weather_code'], ascending=[False, True, True])

# %%
df_sorted.head(5)
# Out:
#            cityname                                   coordinates  \
# 33          Bayonne                  ('43.4945144', '-1.4736657')
# 19           Cassis                   ('43.2140359', '5.5396318')
# 32         Biarritz  ('43.471143749999996', '-1.552726590666314')
# 20        Marseille                   ('43.2961743', '5.3699525')
# 21  Aix+en+Provence                   ('43.5298424', '5.4474738')
#
#     temperature_j1  precipitation_j1  weathercode_j1  temperature_j2  \
# 33            20.3               0.0               3            18.8
# 19            15.3               0.0               3            16.3
# 32            20.0               0.0               2            17.8
# 20            16.2               0.0               3            17.4
# 21            13.6               0.0               3            16.1
#
#     precipitation_j2  weathercode_j2  temperature_j3  precipitation_j3  \
# 33               0.0               1            20.9               0.0
# ...
